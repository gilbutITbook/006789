# %% [markdown]
# <a href="https://colab.research.google.com/github/kslim1025/Tensorflow_Clab/blob/master/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ctrl+enter를 사용한 런타임가능
try:
  # %tensorflow_version only exists in Colab
  # %tensorflow_version 2.x
except Exception:
  pass
# 넘파이는 수학과 과학 연산에 특화된 파이썬 모듈로 딥러닝에서도 유용하게 사용된다.
import tensorflow as tf
import matplotlib.pyplot as plt

x = range(30);
# 최소값이 3 이고 최대값이 10 x의 범위는 30까지
y = tf.random.normal([30],3,10);

plt.plot(x,y);
plt.show();
